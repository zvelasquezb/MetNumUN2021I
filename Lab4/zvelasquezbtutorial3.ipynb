# %%
def product(x,y):
    return x*y
print product(2,3)
[out]: 6
print product(5,10)
[out]: 50

# %%
#mi ejemplo
def sum(a,b):
  return a+b

print(sum(100,1))

print(sum(100,2))
# Out:
# 101
# 102

# %%
def say_hi():
    print('Welcome to QuantConnect')
say_hi()
# Out:
#   File "<ipython-input-4-ceddb0dc7206>", line 2
#     print "Welcome to QuantConnect'
#                                    ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Welcome to QuantConnect')?

# %%
#mi ejemplo
def hola():
    print ("hola")
hola()
# Out:
# hola

# %%
print(range(10))
print(range(1,11))
print(range(1,11,2))
# Out:
# range(0, 10)
# range(1, 11)
# range(1, 11, 2)

# %%
#mi ejempli
print(range(-1))
print(range(0))
print(range(1))
# Out:
# range(0, -1)
# range(0, 0)
# range(0, 1)

# %%
tickers = ['AAPL','GOOG','IBM','FB','F','V', 'G', 'GE']
print('The length of tickers is {}'.format(len(tickers)))
for i in range(len(tickers)):
    print(tickers[i])
# Out:
# The length of tickers is 8
# AAPL
# GOOG
# IBM
# FB
# F
# V
# G
# GE

# %%
#Mi ejemplo
t = ['AAPL','TSLA','IBM','FB']
print('The length of tickers is {}'.format(len(tickers)))
for i in range(len(t)):
    print(t[i])
# Out:
# The length of tickers is 4
# AAPL
# TSLA
# IBM
# FB

# %%
tickers = ['AAPL','GOOG','IBM','FB','F','V', 'G', 'GE']
print(list(map(len,tickers)))
# Out:
# [4, 4, 3, 2, 1, 1, 1, 2]

# %%
#mi ejemplo
ti = ['AAPL','TSLA','IBM','FB']
print(list(map(len,ti)))
# Out:
# [4, 4, 3, 2]

# %%
list(map(lambda x: x**2, range(10)))
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
#Mi ejemplo
list(map(lambda x: x**2, range(1,10)))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
list(map(lambda x, y: x+y, [1,2,3,4,5],[5,4,3,2,1]))
# Out:
# [6, 6, 6, 6, 6]

# %%
list(map(lambda x, y: x+y, [1,2,3,4,5],[5,4,3,2,1]))

# %%
#mi ejemplo
list(map(lambda x, y: x+y, [0,1,0,0,1],[5,4,3,2,1]))
# Out:
# [5, 5, 3, 2, 2]

# %%
sorted([5,2,3,4,1])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Mi ejemplo
sorted([30,20,20,10,0])
# Out:
# [0, 10, 20, 20, 30]

# %%
price_list = [('AAPL',144.09),('GOOG',911.71),('MSFT',69),('FB',150),('WMT',75.32)]
sorted(price_list, key = lambda x: x[1])
# Out:
# [('MSFT', 69), ('WMT', 75.32), ('AAPL', 144.09), ('FB', 150), ('GOOG', 911.71)]

# %%
#Mi ejemplo
price_list = [('AAPL',1),('GOOG',1),('MSFT',2),('FB',4),('TSLA',100)]
sorted(price_list, key = lambda x: x[1])
# Out:
# [('AAPL', 1), ('GOOG', 1), ('MSFT', 2), ('FB', 4), ('TSLA', 100)]

# %%
price_list = [('AAPL',144.09),('GOOG',911.71),('MSFT',69),('FB',150),('WMT',75.32)]
sorted(price_list, key = lambda x: x[1],reverse = True)
# Out:
# [('GOOG', 911.71), ('FB', 150), ('AAPL', 144.09), ('WMT', 75.32), ('MSFT', 69)]

# %%
#mi ejemplo
price_list = [('AAPL',1),('GOOG',1),('MSFT',2),('FB',4),('TSLA',100)]
sorted(price_list, key = lambda x: x[1],reverse = True)
# Out:
# [('TSLA', 100), ('FB', 4), ('MSFT', 2), ('AAPL', 1), ('GOOG', 1)]

# %%
price_list = [('AAPL',144.09),('GOOG',911.71),('MSFT',69),('FB',150),('WMT',75.32)]
price_list.sort(key = lambda x: x[1])
print(price_list)
# Out:
# [('MSFT', 69), ('WMT', 75.32), ('AAPL', 144.09), ('FB', 150), ('GOOG', 911.71)]

# %%
#mi ejemplo
price_list = [('AAPL',1),('GOOG',1),('MSFT',2),('FB',4),('TSLA',100)]
price_list.sort(key = lambda x: x[1])
print(price_list)
# Out:
# [('AAPL', 1), ('GOOG', 1), ('MSFT', 2), ('FB', 4), ('TSLA', 100)]

# %%
class stock:
    def __init__(self, ticker, open, close, volume):
        self.ticker = ticker
        self.open = open
        self.close = close
        self.volume = volume
        self.rate_return = float(close)/open - 1
 
    def update(self, open, close):
        self.open = open
        self.close = close
        self.rate_return = float(self.close)/self.open - 1
 
    def print_return(self):
        print(self.rate_return)

# %%
#mi ejemplo
class carro:
    def __init__(modelo, color, velocidad, puertas, peso):
        modelo.color = color
        modelo.velocidad = open
        modelo.puertas = puertas
        modelo.peso = peso
        
    def updat(modelo, color, velocidad):
        modelo.color = color
        modelo.velocidad = velocidad
        
    def print_return(modelo):
        print(modelo.velocidad)

# %%
apple = stock('AAPL', 143.69, 144.09, 20109375)
google = stock('GOOG', 898.7, 911.7, 1561616)

# %%
#mi ejemplo
mer = carro('chevi', "azul", 50, 4)
to = carro('merce', "roj]o", 30, 2)

# %%
apple.ticker
google.print_return()
google.update(912.8,913.4)
google.print_return()
# Out:
# 0.014465338822744034
# 0.0006573181419806673

# %%
#mi ejemplo
mer.updat("qwe","ri")
to.updat("asd","asd")
to.print_return()
# Out:
# asd

# %%
apple.ceo = 'Tim Cook'
apple.ceo
# Out:
# 'Tim Cook'

# %%
#mi ejemplo
to.nan="nan"
to.nan
# Out:
# 'nan'

# %%
dir(apple)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'ceo',
#  'close',
#  'open',
#  'print_return',
#  'rate_return',
#  'ticker',
#  'update',
#  'volume']

# %%
#mi ejemplo
dir(to)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'color',
#  'nan',
#  'peso',
#  'print_return',
#  'puertas',
#  'updat',
#  'velocidad']

# %%
class child(stock):
    def __init__(self,name):
        self.name = name

# %%
#mi ejemplo
class nan(carro):
  def __init__(self,nit):
    self.nit=nit

# %%
aa = child('aa')
print(aa.name)
aa.update(100,102)
print(aa.open)
print(aa.close)
print(aa.print_return())
# Out:
# aa
# 100
# 102
# 0.020000000000000018
# None

# %%
#mi ejemplo
as123 = nan('as123')
print(as123.nit)
as123.updat("asd","asd")
print(as123.print_return())
# Out:
# as123
# asd
# None
