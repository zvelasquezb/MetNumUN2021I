# %% [markdown]
# Linkedin:https://www.linkedin.com/in/zamir-velasquez-beltran-49b52b20b/

# %% [markdown]
# **Cognitive class**
#
# * Data Analysis with Python:https://courses.cognitiveclass.ai/certificates/f80223c74fcb42adaec88a31828cac24
# * Data Visualization with Python:https://courses.cognitiveclass.ai/certificates/e9a7d9d9972e496688d79b80eac2ea95
# * Python 101 for Data Science:https://courses.cognitiveclass.ai/certificates/f77e5b3d381c461a9386e783a240b121

# %% [markdown]
# ![image.png](data:image/png;base64,...)
